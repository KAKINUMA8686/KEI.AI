# %%
import json

# 辞書データ
sex_mapping = {"牡": 0, "牝": 1, "セ": 2}

# ファイル名
filename = "sex.json"

# JSON ファイルに保存
with open(filename, "w", encoding="utf-8") as f:
    json.dump(sex_mapping, f, ensure_ascii=False, indent=4)

# %%
weather_mapping = {"晴" : 0,"曇" : 1,"雨" : 2, "小雨" : 3, "雪" : 4, "小雪" : 5}
filename = "weather.json"

with open(filename, "w", encoding="utf-8") as f:
    json.dump(weather_mapping, f, ensure_ascii=False, indent=4)

# %%
race_type_mapping = {"ダ" : 0,"芝" : 1,"障" : 2}
filename = "race_type.json"

with open(filename, "w", encoding="utf-8") as f:
    json.dump(race_type_mapping, f, ensure_ascii=False, indent=4)

# %%
ground_state_mapping = {"良" : 0 ,"稍" : 1,"重" : 2,"不" : 3}
filename = "ground_state.json"

with open(filename, "w", encoding="utf-8") as f:
    json.dump(ground_state_mapping, f, ensure_ascii=False, indent=4)

# %%
race_class_mapping = {"新馬" : 0,
                      "未勝利" : 1,
                      "1勝クラス" : 2,
                      "2勝クラス" : 3,
                      "3勝クラス" : 4,
                      "オープン" : 5,
                      "GIII": 6,
                      "GII" : 7,
                      "GI" : 8,
                      "OP" : 5,
                      "特別" : 5,
                      "500万下" : 2,
                      "1000万下" : 3,
                      "1600万下" : 4}
filename = "race_class.json"

with open(filename, "w", encoding="utf-8") as f:
    json.dump(race_class_mapping, f, ensure_ascii=False, indent=4)
